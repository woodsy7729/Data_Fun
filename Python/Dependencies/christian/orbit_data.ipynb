# %%
import pandas as pd
df = pd.read_excel("Orbit_9am_Term_1.xlsx", sheetname="pandas")
df
# Out:
#                  Date   Week                                      Big Idea  \
# 0  2018-04-02 00:00:00      1       The King worth following - Luke 5:1-11
# 1  2018-11-02 00:00:00      2          The Majestic King - Matthew 17:1- 9
# 2                 18/2      3             The Miraculous King - Mark 1 + 2
# 3                 25/2      4          The Trusted King - Matthew 14:22-33
# 4  2018-04-03 00:00:00      5             The Real King - Matthew 16:13-28
# 5  2018-11-03 00:00:00      6               The Servant King -John 13:1-38
# 6                 18/4      7  The Betrayed King - Matthew 26:31-58, 69-75
# 7                 25/4      8         The Rejected King - John 18:28-19:42
# 8  2018-01-04 00:00:00      9                 The Risen King -John 20:1-29
# 9  2018-08-04 00:00:00     10             The Forgiving King -John 21:1-19
#
#      Talk  Review Memory Verse   Prayer             Activity Game- Energy  \
# ...
